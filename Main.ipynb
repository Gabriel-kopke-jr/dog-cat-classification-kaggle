# %%
# !pip install opencv-python
import matplotlib.pyplot as plt
import cv2
import seaborn as sns
# %run Methods.ipynb

# %%
imagem, imagem_cinza = read_image(1,"cat")

# %%
plt.imshow(imagem)

# %%
faces_gato = classifier(imagem_cinza,1.3,3)
faces_gato
# Out:
# array([[130, 163,  36,  36]])

# %%
imagem = mark_rec(imagem,faces_gato)

# %%
plt.imshow(imagem)
