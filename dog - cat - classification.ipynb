# %%
# !pip install opencv-python
import matplotlib.pyplot as plt
import cv2
import seaborn as sns

# %%
imagem = cv2.imread("C:\cats\cat.2.jpg")
imagem_rgb = cv2.cvtColor(imagem,cv2.COLOR_BGR2RGB)
imagem_cinza = cv2.cvtColor(imagem,cv2.COLOR_BGR2GRAY)
plt.imshow(imagem)

# %%
classificador = cv2.CascadeClassifier("C:\haarcascade_frontalcatface_default.xml")

# %%
cat_face = classificador.detectMultiScale(imagem_cinza,1.3,10)
cat_face
# Out:
# array([[139, 300,  73,  73],
#        [ 44,  94, 113, 113]])

# %%
cont=0
for (x, y, w, h)   in cat_face:
  #if cont== 0:
	cv2.rectangle(imagem, (x, y), (x + w, y + h), (0, 0, 255), 3)
  #cont+=1

# %%
plt.imshow(imagem)
